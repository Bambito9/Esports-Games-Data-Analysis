# %%
# importing required libraries
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/bambito9/Esports-Data-Analysis/API Requests/League of Legends/Datasets/Amateur/FinalAmateurPlayersDataset.csv", dtype = {'skillSlot': str, 'buildingType': str, 'lane': str, 'monster': str, "itemName": str})
df
# Out:
#                  gameId  team       summoner region champion  timestamp  \
# 0       EUW1_6274275803  Blue  anonymous 125   euw1   Twitch   0.000000
# 1       EUW1_6274275803  Blue  anonymous 125   euw1   Twitch   1.000200
# 2       EUW1_6274275803  Blue  anonymous 125   euw1   Twitch   0.495733
# 3       EUW1_6274275803  Blue  anonymous 125   euw1   Twitch   2.000517
# 4       EUW1_6274275803  Blue  anonymous 125   euw1   Twitch   1.979017
# ...                 ...   ...            ...    ...      ...        ...
# 838676  EUW1_6283483863   Red   anonymous 56   euw1    Annie  17.139450
# 838677  EUW1_6283483863   Red   anonymous 56   euw1    Annie  22.688683
# 838678  EUW1_6283483863   Red   anonymous 56   euw1    Annie  22.826867
# 838679  EUW1_6283483863   Red   anonymous 56   euw1    Annie  25.901700
# 838680  EUW1_6283483863   Red   anonymous 56   euw1    Annie  27.683317
#
#         coordinate_x  coordinate_y  level  minionsKilled  ...  \
# 0              329.0         650.0    1.0            0.0  ...
# 1             6569.0       11391.0    1.0            0.0  ...
# 2                NaN           NaN    NaN            NaN  ...
# 3             4320.0       12059.0    1.0            0.0  ...
# 4             4245.0       13217.0    NaN            NaN  ...
# ...              ...           ...    ...            ...  ...
# 838676           NaN           NaN    NaN            NaN  ...
# 838677           NaN           NaN    NaN            NaN  ...
# 838678           NaN           NaN    NaN            NaN  ...
# 838679           NaN           NaN    NaN            NaN  ...
# 838680           NaN           NaN    NaN            NaN  ...
#
#         trueDamageTaken  victory       eventType  skillSlot  buildingType  \
# 0                   0.0    False             NaN        NaN           NaN
# 1                   0.0    False             NaN        NaN           NaN
# 2                   NaN    False    SkillLevelUp        1.0           NaN
# 3                   0.0    False             NaN        NaN           NaN
# 4                   NaN    False          Assist        NaN           NaN
# ...                 ...      ...             ...        ...           ...
# 838676              NaN    False  Item purchased        NaN           NaN
# 838677              NaN    False  Item purchased        NaN           NaN
# 838678              NaN    False  Item purchased        NaN           NaN
# 838679              NaN    False  Item purchased        NaN           NaN
# 838680              NaN    False  Item purchased        NaN           NaN
#
#         lane  monster            itemName     role      rank
# 0        NaN      NaN                 NaN  UTILITY  Platinum
# 1        NaN      NaN                 NaN  UTILITY  Platinum
# 2        NaN      NaN                 NaN  UTILITY  Platinum
# 3        NaN      NaN                 NaN  UTILITY  Platinum
# 4        NaN      NaN                 NaN  UTILITY  Platinum
# ...      ...      ...                 ...      ...       ...
# 838676   NaN      NaN           Kindlegem  UTILITY      Gold
# 838677   NaN      NaN        Knight's Vow  UTILITY      Gold
# 838678   NaN      NaN     Glacial Buckler  UTILITY      Gold
# 838679   NaN      NaN           Kindlegem  UTILITY      Gold
# 838680   NaN      NaN  Zeke's Convergence  UTILITY      Gold
#
# [838681 rows x 56 columns]

# %%
len(np.unique(df["gameId"]))
# Out:
# 9617

# %%
temp_df = df[df["timestamp"].values == 0.0]
temp_df
# Out:
#                  gameId  team       summoner region  champion  timestamp  \
# 0       EUW1_6274275803  Blue  anonymous 125   euw1    Twitch        0.0
# 68      EUW1_6274236837  Blue  anonymous 125   euw1     Senna        0.0
# 101     EUW1_6274179434  Blue  anonymous 125   euw1  Nautilus        0.0
# 162     EUW1_6274101916   Red  anonymous 125   euw1     Senna        0.0
# 259     EUW1_6274059942  Blue  anonymous 125   euw1     Senna        0.0
# ...                 ...   ...            ...    ...       ...        ...
# 643302  EUW1_6289889931   Red  anonymous 180   euw1    Yorick        0.0
# 643354  EUW1_6289861117  Blue  anonymous 180   euw1    Yorick        0.0
# 643401  EUW1_6289796520   Red  anonymous 180   euw1    Yorick        0.0
# 643476  EUW1_6289751522  Blue  anonymous 180   euw1    Yorick        0.0
# 643519  EUW1_6289696584  Blue  anonymous 180   euw1     Nasus        0.0
#
#         coordinate_x  coordinate_y  level  minionsKilled  ...  \
# 0              329.0         650.0    1.0            0.0  ...
# 68             329.0         650.0    1.0            0.0  ...
# 101            329.0         650.0    1.0            0.0  ...
# 162          14404.0       14201.0    1.0            0.0  ...
# 259            329.0         650.0    1.0            0.0  ...
# ...              ...           ...    ...            ...  ...
# 643302       14180.0       14271.0    1.0            0.0  ...
# 643354         554.0         581.0    1.0            0.0  ...
# 643401       14180.0       14271.0    1.0            0.0  ...
# 643476         554.0         581.0    1.0            0.0  ...
# 643519         554.0         581.0    1.0            0.0  ...
#
#         trueDamageTaken  victory  eventType  skillSlot  buildingType  lane  \
# 0                   0.0    False        NaN        NaN           NaN   NaN
# 68                  0.0    False        NaN        NaN           NaN   NaN
# 101                 0.0    False        NaN        NaN           NaN   NaN
# 162                 0.0     True        NaN        NaN           NaN   NaN
# 259                 0.0     True        NaN        NaN           NaN   NaN
# ...                 ...      ...        ...        ...           ...   ...
# 643302              0.0    False        NaN        NaN           NaN   NaN
# 643354              0.0     True        NaN        NaN           NaN   NaN
# 643401              0.0     True        NaN        NaN           NaN   NaN
# 643476              0.0    False        NaN        NaN           NaN   NaN
# 643519              0.0    False        NaN        NaN           NaN   NaN
#
#         monster  itemName     role      rank
# 0           NaN       NaN  UTILITY  Platinum
# 68          NaN       NaN  UTILITY  Platinum
# 101         NaN       NaN  UTILITY  Platinum
# 162         NaN       NaN  UTILITY  Platinum
# 259         NaN       NaN  UTILITY  Platinum
# ...         ...       ...      ...       ...
# 643302      NaN       NaN      TOP      Gold
# 643354      NaN       NaN      TOP      Gold
# 643401      NaN       NaN      TOP      Gold
# 643476      NaN       NaN      TOP      Gold
# 643519      NaN       NaN      TOP      Gold
#
# [9653 rows x 56 columns]

# %%
len(np.unique(temp_df["gameId"]))
# Out:
# 9617

# %%
temp_df["gameId"].value_counts()
# Out:
# EUW1_6279059476    2
# EUW1_6281200071    2
# EUW1_6289114118    2
# EUW1_6274421335    2
# EUW1_6274345097    2
#                   ..
# EUW1_6281803045    1
# EUW1_6281781087    1
# EUW1_6281769088    1
# EUW1_6281758071    1
# EUW1_6289696584    1
# Name: gameId, Length: 9617, dtype: int64

# %% [markdown]
# ---
#
# Blue Side Win Rate

# %%
blueSideWinRate_df = temp_df[temp_df["team"] == "Blue"]
blueSideWinRate_df
# Out:
#                  gameId  team       summoner region   champion  timestamp  \
# 0       EUW1_6274275803  Blue  anonymous 125   euw1     Twitch        0.0
# 68      EUW1_6274236837  Blue  anonymous 125   euw1      Senna        0.0
# 101     EUW1_6274179434  Blue  anonymous 125   euw1   Nautilus        0.0
# 259     EUW1_6274059942  Blue  anonymous 125   euw1      Senna        0.0
# 337     EUW1_6274015114  Blue  anonymous 125   euw1      Senna        0.0
# ...                 ...   ...            ...    ...        ...        ...
# 643195  EUW1_6289299471  Blue  anonymous 176   euw1  Gangplank        0.0
# 643241  EUW1_6289931620  Blue  anonymous 180   euw1     Yorick        0.0
# 643354  EUW1_6289861117  Blue  anonymous 180   euw1     Yorick        0.0
# 643476  EUW1_6289751522  Blue  anonymous 180   euw1     Yorick        0.0
# 643519  EUW1_6289696584  Blue  anonymous 180   euw1      Nasus        0.0
#
#         coordinate_x  coordinate_y  level  minionsKilled  ...  \
# 0              329.0         650.0    1.0            0.0  ...
# 68             329.0         650.0    1.0            0.0  ...
# 101            329.0         650.0    1.0            0.0  ...
# 259            329.0         650.0    1.0            0.0  ...
# 337            329.0         650.0    1.0            0.0  ...
# ...              ...           ...    ...            ...  ...
# 643195         554.0         581.0    1.0            0.0  ...
# 643241         554.0         581.0    1.0            0.0  ...
# 643354         554.0         581.0    1.0            0.0  ...
# 643476         554.0         581.0    1.0            0.0  ...
# 643519         554.0         581.0    1.0            0.0  ...
#
#         trueDamageTaken  victory  eventType  skillSlot  buildingType  lane  \
# 0                   0.0    False        NaN        NaN           NaN   NaN
# 68                  0.0    False        NaN        NaN           NaN   NaN
# 101                 0.0    False        NaN        NaN           NaN   NaN
# 259                 0.0     True        NaN        NaN           NaN   NaN
# 337                 0.0     True        NaN        NaN           NaN   NaN
# ...                 ...      ...        ...        ...           ...   ...
# 643195              0.0    False        NaN        NaN           NaN   NaN
# 643241              0.0     True        NaN        NaN           NaN   NaN
# 643354              0.0     True        NaN        NaN           NaN   NaN
# 643476              0.0    False        NaN        NaN           NaN   NaN
# 643519              0.0    False        NaN        NaN           NaN   NaN
#
#         monster  itemName     role      rank
# 0           NaN       NaN  UTILITY  Platinum
# 68          NaN       NaN  UTILITY  Platinum
# 101         NaN       NaN  UTILITY  Platinum
# 259         NaN       NaN  UTILITY  Platinum
# 337         NaN       NaN  UTILITY  Platinum
# ...         ...       ...      ...       ...
# 643195      NaN       NaN      TOP      Gold
# 643241      NaN       NaN      TOP      Gold
# 643354      NaN       NaN      TOP      Gold
# 643476      NaN       NaN      TOP      Gold
# 643519      NaN       NaN      TOP      Gold
#
# [4732 rows x 56 columns]

# %%
len(np.unique(blueSideWinRate_df["gameId"]))
# Out:
# 4718

# %%
blueVictory = blueSideWinRate_df["victory"].value_counts()
blueVictory
# Out:
# True     2541
# False    2191
# Name: victory, dtype: int64

# %%
winRateBlueSide = (blueVictory[1]/ blueSideWinRate_df.shape[0]) * 100
winRateBlueSide
# Out:
# 53.69822485207101

# %% [markdown]
# ---
#
# Red Side Win Rate

# %%
redSideWinRate_df = temp_df[temp_df["team"] == "Red"]
redSideWinRate_df
# Out:
#                  gameId team       summoner region  champion  timestamp  \
# 162     EUW1_6274101916  Red  anonymous 125   euw1     Senna        0.0
# 466     EUW1_6273937462  Red  anonymous 125   euw1      Bard        0.0
# 597     EUW1_6273872012  Red  anonymous 125   euw1  Nautilus        0.0
# 650     EUW1_6273829246  Red  anonymous 125   euw1     Senna        0.0
# 877     EUW1_6273778414  Red  anonymous 125   euw1  Nautilus        0.0
# ...                 ...  ...            ...    ...       ...        ...
# 642925  EUW1_6289397856  Red  anonymous 172   euw1      Ekko        0.0
# 642992  EUW1_6289552171  Red  anonymous 176   euw1    Darius        0.0
# 643122  EUW1_6289333450  Red  anonymous 176   euw1    Darius        0.0
# 643302  EUW1_6289889931  Red  anonymous 180   euw1    Yorick        0.0
# 643401  EUW1_6289796520  Red  anonymous 180   euw1    Yorick        0.0
#
#         coordinate_x  coordinate_y  level  minionsKilled  ...  \
# 162          14404.0       14201.0    1.0            0.0  ...
# 466          14404.0       14201.0    1.0            0.0  ...
# 597          14404.0       14201.0    1.0            0.0  ...
# 650          14404.0       14201.0    1.0            0.0  ...
# 877          14404.0       14201.0    1.0            0.0  ...
# ...              ...           ...    ...            ...  ...
# 642925       14176.0       14506.0    1.0            0.0  ...
# 642992       14180.0       14271.0    1.0            0.0  ...
# 643122       14180.0       14271.0    1.0            0.0  ...
# 643302       14180.0       14271.0    1.0            0.0  ...
# 643401       14180.0       14271.0    1.0            0.0  ...
#
#         trueDamageTaken  victory  eventType  skillSlot  buildingType  lane  \
# 162                 0.0     True        NaN        NaN           NaN   NaN
# 466                 0.0     True        NaN        NaN           NaN   NaN
# 597                 0.0    False        NaN        NaN           NaN   NaN
# 650                 0.0     True        NaN        NaN           NaN   NaN
# 877                 0.0     True        NaN        NaN           NaN   NaN
# ...                 ...      ...        ...        ...           ...   ...
# 642925              0.0     True        NaN        NaN           NaN   NaN
# 642992              0.0    False        NaN        NaN           NaN   NaN
# 643122              0.0     True        NaN        NaN           NaN   NaN
# 643302              0.0    False        NaN        NaN           NaN   NaN
# 643401              0.0     True        NaN        NaN           NaN   NaN
#
#         monster  itemName     role      rank
# 162         NaN       NaN  UTILITY  Platinum
# 466         NaN       NaN  UTILITY  Platinum
# 597         NaN       NaN  UTILITY  Platinum
# 650         NaN       NaN  UTILITY  Platinum
# 877         NaN       NaN  UTILITY  Platinum
# ...         ...       ...      ...       ...
# 642925      NaN       NaN   JUNGLE      Gold
# 642992      NaN       NaN      TOP      Gold
# 643122      NaN       NaN      TOP      Gold
# 643302      NaN       NaN      TOP      Gold
# 643401      NaN       NaN      TOP      Gold
#
# [4921 rows x 56 columns]

# %%
len(np.unique(redSideWinRate_df["gameId"]))
# Out:
# 4906

# %%
redVictory = redSideWinRate_df["victory"].value_counts()
redVictory
# Out:
# True     2568
# False    2353
# Name: victory, dtype: int64

# %%
winRateRedSide = (redVictory[1]/ redSideWinRate_df.shape[0]) * 100
winRateRedSide
# Out:
# 52.18451534241007

# %% [markdown]
# ---
#
# Red Side vs Blue Side win rate

# %%
wins_df = temp_df[temp_df["victory"] == True]

# %%
b = (blueVictory[1]/ wins_df.shape[0]) * 100
b
# Out:
# 49.73576042278333

# %%
r = (redVictory[1]/ wins_df.shape[0]) * 100
r
# Out:
# 50.26423957721667

# %% [markdown]
# ---
#
# Win rate for each player in each side

# %%
players_df = np.unique(wins_df["summoner"])
games_df = np.unique(wins_df["gameId"])
for player in players_df:
    temp2_df = wins_df[wins_df["summoner"] == player]
    print("{} has a total of {} victories\n".format(player, temp2_df.shape[0]))


    #Player Red side Victories
    playerWinsRedSide_df = temp2_df[temp2_df["team"] == "Red"]
    playerWinsRedSide = len(np.unique(playerWinsRedSide_df["gameId"]))
    print("{} has {} victories on red side".format(player, playerWinsRedSide))

    #Player Red side Victories
    playerWinsBlueSide_df = temp2_df[temp2_df["team"] == "Blue"]
    playerWinsBlueSide = len(np.unique(playerWinsBlueSide_df["gameId"]))
    print("{} has {} victories on blue side\n".format(player, playerWinsBlueSide))

    print("{} has {:.2f} win rate on blue side".format(player, (playerWinsBlueSide/temp2_df.shape[0]) * 100))
    print("{} has {:.2f} win rate on red side\n".format(player, (playerWinsRedSide/temp2_df.shape[0]) * 100))

    print("-------------------------------------------\n")
# Out:
# anonymous 1 has a total of 30 victories
#
# anonymous 1 has 13 victories on red side
# anonymous 1 has 17 victories on blue side
#
# anonymous 1 has 56.67 win rate on blue side
# anonymous 1 has 43.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 10 has a total of 30 victories
#
# anonymous 10 has 12 victories on red side
# anonymous 10 has 18 victories on blue side
#
# anonymous 10 has 60.00 win rate on blue side
# anonymous 10 has 40.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 100 has a total of 39 victories
#
# anonymous 100 has 24 victories on red side
# anonymous 100 has 15 victories on blue side
#
# anonymous 100 has 38.46 win rate on blue side
# anonymous 100 has 61.54 win rate on red side
#
# -------------------------------------------
#
# anonymous 101 has a total of 50 victories
#
# anonymous 101 has 22 victories on red side
# anonymous 101 has 28 victories on blue side
#
# anonymous 101 has 56.00 win rate on blue side
# anonymous 101 has 44.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 102 has a total of 28 victories
#
# anonymous 102 has 12 victories on red side
# anonymous 102 has 16 victories on blue side
#
# anonymous 102 has 57.14 win rate on blue side
# anonymous 102 has 42.86 win rate on red side
#
# -------------------------------------------
#
# anonymous 103 has a total of 15 victories
#
# anonymous 103 has 10 victories on red side
# anonymous 103 has 5 victories on blue side
#
# anonymous 103 has 33.33 win rate on blue side
# anonymous 103 has 66.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 104 has a total of 55 victories
#
# anonymous 104 has 26 victories on red side
# anonymous 104 has 29 victories on blue side
#
# anonymous 104 has 52.73 win rate on blue side
# anonymous 104 has 47.27 win rate on red side
#
# -------------------------------------------
#
# anonymous 105 has a total of 40 victories
#
# anonymous 105 has 24 victories on red side
# anonymous 105 has 16 victories on blue side
#
# anonymous 105 has 40.00 win rate on blue side
# anonymous 105 has 60.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 106 has a total of 35 victories
#
# anonymous 106 has 17 victories on red side
# anonymous 106 has 18 victories on blue side
#
# anonymous 106 has 51.43 win rate on blue side
# anonymous 106 has 48.57 win rate on red side
#
# -------------------------------------------
#
# anonymous 108 has a total of 18 victories
#
# anonymous 108 has 7 victories on red side
# anonymous 108 has 11 victories on blue side
#
# anonymous 108 has 61.11 win rate on blue side
# anonymous 108 has 38.89 win rate on red side
#
# -------------------------------------------
#
# anonymous 109 has a total of 72 victories
#
# anonymous 109 has 40 victories on red side
# anonymous 109 has 32 victories on blue side
#
# anonymous 109 has 44.44 win rate on blue side
# anonymous 109 has 55.56 win rate on red side
#
# -------------------------------------------
#
# anonymous 11 has a total of 23 victories
#
# anonymous 11 has 10 victories on red side
# anonymous 11 has 13 victories on blue side
#
# anonymous 11 has 56.52 win rate on blue side
# anonymous 11 has 43.48 win rate on red side
#
# -------------------------------------------
#
# anonymous 110 has a total of 24 victories
#
# anonymous 110 has 12 victories on red side
# anonymous 110 has 12 victories on blue side
#
# anonymous 110 has 50.00 win rate on blue side
# anonymous 110 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 111 has a total of 23 victories
#
# anonymous 111 has 10 victories on red side
# anonymous 111 has 13 victories on blue side
#
# anonymous 111 has 56.52 win rate on blue side
# anonymous 111 has 43.48 win rate on red side
#
# -------------------------------------------
#
# anonymous 112 has a total of 48 victories
#
# anonymous 112 has 25 victories on red side
# anonymous 112 has 23 victories on blue side
#
# anonymous 112 has 47.92 win rate on blue side
# anonymous 112 has 52.08 win rate on red side
#
# -------------------------------------------
#
# anonymous 113 has a total of 16 victories
#
# anonymous 113 has 8 victories on red side
# anonymous 113 has 8 victories on blue side
#
# anonymous 113 has 50.00 win rate on blue side
# anonymous 113 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 114 has a total of 17 victories
#
# anonymous 114 has 7 victories on red side
# anonymous 114 has 10 victories on blue side
#
# anonymous 114 has 58.82 win rate on blue side
# anonymous 114 has 41.18 win rate on red side
#
# -------------------------------------------
#
# anonymous 115 has a total of 26 victories
#
# anonymous 115 has 10 victories on red side
# anonymous 115 has 16 victories on blue side
#
# anonymous 115 has 61.54 win rate on blue side
# anonymous 115 has 38.46 win rate on red side
#
# -------------------------------------------
#
# anonymous 116 has a total of 23 victories
#
# anonymous 116 has 8 victories on red side
# anonymous 116 has 15 victories on blue side
#
# anonymous 116 has 65.22 win rate on blue side
# anonymous 116 has 34.78 win rate on red side
#
# -------------------------------------------
#
# anonymous 117 has a total of 40 victories
#
# anonymous 117 has 22 victories on red side
# anonymous 117 has 18 victories on blue side
#
# anonymous 117 has 45.00 win rate on blue side
# anonymous 117 has 55.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 118 has a total of 10 victories
#
# anonymous 118 has 3 victories on red side
# anonymous 118 has 7 victories on blue side
#
# anonymous 118 has 70.00 win rate on blue side
# anonymous 118 has 30.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 119 has a total of 52 victories
#
# anonymous 119 has 28 victories on red side
# anonymous 119 has 24 victories on blue side
#
# anonymous 119 has 46.15 win rate on blue side
# anonymous 119 has 53.85 win rate on red side
#
# -------------------------------------------
#
# anonymous 12 has a total of 22 victories
#
# anonymous 12 has 13 victories on red side
# anonymous 12 has 9 victories on blue side
#
# anonymous 12 has 40.91 win rate on blue side
# anonymous 12 has 59.09 win rate on red side
#
# -------------------------------------------
#
# anonymous 120 has a total of 69 victories
#
# anonymous 120 has 34 victories on red side
# anonymous 120 has 35 victories on blue side
#
# anonymous 120 has 50.72 win rate on blue side
# anonymous 120 has 49.28 win rate on red side
#
# -------------------------------------------
#
# anonymous 121 has a total of 28 victories
#
# anonymous 121 has 17 victories on red side
# anonymous 121 has 11 victories on blue side
#
# anonymous 121 has 39.29 win rate on blue side
# anonymous 121 has 60.71 win rate on red side
#
# -------------------------------------------
#
# anonymous 122 has a total of 18 victories
#
# anonymous 122 has 7 victories on red side
# anonymous 122 has 11 victories on blue side
#
# anonymous 122 has 61.11 win rate on blue side
# anonymous 122 has 38.89 win rate on red side
#
# -------------------------------------------
#
# anonymous 123 has a total of 17 victories
#
# anonymous 123 has 11 victories on red side
# anonymous 123 has 6 victories on blue side
#
# anonymous 123 has 35.29 win rate on blue side
# anonymous 123 has 64.71 win rate on red side
#
# -------------------------------------------
#
# anonymous 125 has a total of 47 victories
#
# anonymous 125 has 26 victories on red side
# anonymous 125 has 21 victories on blue side
#
# anonymous 125 has 44.68 win rate on blue side
# anonymous 125 has 55.32 win rate on red side
#
# -------------------------------------------
#
# anonymous 126 has a total of 22 victories
#
# anonymous 126 has 11 victories on red side
# anonymous 126 has 11 victories on blue side
#
# anonymous 126 has 50.00 win rate on blue side
# anonymous 126 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 129 has a total of 12 victories
#
# anonymous 129 has 7 victories on red side
# anonymous 129 has 5 victories on blue side
#
# anonymous 129 has 41.67 win rate on blue side
# anonymous 129 has 58.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 13 has a total of 35 victories
#
# anonymous 13 has 17 victories on red side
# anonymous 13 has 18 victories on blue side
#
# anonymous 13 has 51.43 win rate on blue side
# anonymous 13 has 48.57 win rate on red side
#
# -------------------------------------------
#
# anonymous 130 has a total of 30 victories
#
# anonymous 130 has 15 victories on red side
# anonymous 130 has 15 victories on blue side
#
# anonymous 130 has 50.00 win rate on blue side
# anonymous 130 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 131 has a total of 35 victories
#
# anonymous 131 has 16 victories on red side
# anonymous 131 has 19 victories on blue side
#
# anonymous 131 has 54.29 win rate on blue side
# anonymous 131 has 45.71 win rate on red side
#
# -------------------------------------------
#
# anonymous 132 has a total of 25 victories
#
# anonymous 132 has 15 victories on red side
# anonymous 132 has 10 victories on blue side
#
# anonymous 132 has 40.00 win rate on blue side
# anonymous 132 has 60.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 135 has a total of 25 victories
#
# anonymous 135 has 14 victories on red side
# anonymous 135 has 11 victories on blue side
#
# anonymous 135 has 44.00 win rate on blue side
# anonymous 135 has 56.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 137 has a total of 14 victories
#
# anonymous 137 has 8 victories on red side
# anonymous 137 has 6 victories on blue side
#
# anonymous 137 has 42.86 win rate on blue side
# anonymous 137 has 57.14 win rate on red side
#
# -------------------------------------------
#
# anonymous 139 has a total of 18 victories
#
# anonymous 139 has 7 victories on red side
# anonymous 139 has 11 victories on blue side
#
# anonymous 139 has 61.11 win rate on blue side
# anonymous 139 has 38.89 win rate on red side
#
# -------------------------------------------
#
# anonymous 14 has a total of 29 victories
#
# anonymous 14 has 10 victories on red side
# anonymous 14 has 19 victories on blue side
#
# anonymous 14 has 65.52 win rate on blue side
# anonymous 14 has 34.48 win rate on red side
#
# -------------------------------------------
#
# anonymous 140 has a total of 12 victories
#
# anonymous 140 has 7 victories on red side
# anonymous 140 has 5 victories on blue side
#
# anonymous 140 has 41.67 win rate on blue side
# anonymous 140 has 58.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 141 has a total of 10 victories
#
# anonymous 141 has 4 victories on red side
# anonymous 141 has 6 victories on blue side
#
# anonymous 141 has 60.00 win rate on blue side
# anonymous 141 has 40.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 142 has a total of 9 victories
#
# anonymous 142 has 3 victories on red side
# anonymous 142 has 6 victories on blue side
#
# anonymous 142 has 66.67 win rate on blue side
# anonymous 142 has 33.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 143 has a total of 28 victories
#
# anonymous 143 has 20 victories on red side
# anonymous 143 has 8 victories on blue side
#
# anonymous 143 has 28.57 win rate on blue side
# anonymous 143 has 71.43 win rate on red side
#
# -------------------------------------------
#
# anonymous 144 has a total of 16 victories
#
# anonymous 144 has 14 victories on red side
# anonymous 144 has 2 victories on blue side
#
# anonymous 144 has 12.50 win rate on blue side
# anonymous 144 has 87.50 win rate on red side
#
# -------------------------------------------
#
# anonymous 145 has a total of 12 victories
#
# anonymous 145 has 10 victories on red side
# anonymous 145 has 2 victories on blue side
#
# anonymous 145 has 16.67 win rate on blue side
# anonymous 145 has 83.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 146 has a total of 42 victories
#
# anonymous 146 has 19 victories on red side
# anonymous 146 has 23 victories on blue side
#
# anonymous 146 has 54.76 win rate on blue side
# anonymous 146 has 45.24 win rate on red side
#
# -------------------------------------------
#
# anonymous 147 has a total of 28 victories
#
# anonymous 147 has 15 victories on red side
# anonymous 147 has 13 victories on blue side
#
# anonymous 147 has 46.43 win rate on blue side
# anonymous 147 has 53.57 win rate on red side
#
# -------------------------------------------
#
# anonymous 148 has a total of 10 victories
#
# anonymous 148 has 3 victories on red side
# anonymous 148 has 7 victories on blue side
#
# anonymous 148 has 70.00 win rate on blue side
# anonymous 148 has 30.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 15 has a total of 28 victories
#
# anonymous 15 has 14 victories on red side
# anonymous 15 has 14 victories on blue side
#
# anonymous 15 has 50.00 win rate on blue side
# anonymous 15 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 150 has a total of 18 victories
#
# anonymous 150 has 8 victories on red side
# anonymous 150 has 10 victories on blue side
#
# anonymous 150 has 55.56 win rate on blue side
# anonymous 150 has 44.44 win rate on red side
#
# -------------------------------------------
#
# anonymous 151 has a total of 13 victories
#
# anonymous 151 has 6 victories on red side
# anonymous 151 has 7 victories on blue side
#
# anonymous 151 has 53.85 win rate on blue side
# anonymous 151 has 46.15 win rate on red side
#
# -------------------------------------------
#
# anonymous 152 has a total of 9 victories
#
# anonymous 152 has 2 victories on red side
# anonymous 152 has 7 victories on blue side
#
# anonymous 152 has 77.78 win rate on blue side
# anonymous 152 has 22.22 win rate on red side
#
# -------------------------------------------
#
# anonymous 153 has a total of 15 victories
#
# anonymous 153 has 8 victories on red side
# anonymous 153 has 7 victories on blue side
#
# anonymous 153 has 46.67 win rate on blue side
# anonymous 153 has 53.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 154 has a total of 15 victories
#
# anonymous 154 has 7 victories on red side
# anonymous 154 has 8 victories on blue side
#
# anonymous 154 has 53.33 win rate on blue side
# anonymous 154 has 46.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 156 has a total of 28 victories
#
# anonymous 156 has 13 victories on red side
# anonymous 156 has 15 victories on blue side
#
# anonymous 156 has 53.57 win rate on blue side
# anonymous 156 has 46.43 win rate on red side
#
# -------------------------------------------
#
# anonymous 157 has a total of 33 victories
#
# anonymous 157 has 19 victories on red side
# anonymous 157 has 14 victories on blue side
#
# anonymous 157 has 42.42 win rate on blue side
# anonymous 157 has 57.58 win rate on red side
#
# -------------------------------------------
#
# anonymous 158 has a total of 30 victories
#
# anonymous 158 has 11 victories on red side
# anonymous 158 has 19 victories on blue side
#
# anonymous 158 has 63.33 win rate on blue side
# anonymous 158 has 36.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 159 has a total of 13 victories
#
# anonymous 159 has 6 victories on red side
# anonymous 159 has 7 victories on blue side
#
# anonymous 159 has 53.85 win rate on blue side
# anonymous 159 has 46.15 win rate on red side
#
# -------------------------------------------
#
# anonymous 16 has a total of 32 victories
#
# anonymous 16 has 11 victories on red side
# anonymous 16 has 21 victories on blue side
#
# anonymous 16 has 65.62 win rate on blue side
# anonymous 16 has 34.38 win rate on red side
#
# -------------------------------------------
#
# anonymous 160 has a total of 32 victories
#
# anonymous 160 has 16 victories on red side
# anonymous 160 has 16 victories on blue side
#
# anonymous 160 has 50.00 win rate on blue side
# anonymous 160 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 161 has a total of 34 victories
#
# anonymous 161 has 13 victories on red side
# anonymous 161 has 21 victories on blue side
#
# anonymous 161 has 61.76 win rate on blue side
# anonymous 161 has 38.24 win rate on red side
#
# -------------------------------------------
#
# anonymous 162 has a total of 22 victories
#
# anonymous 162 has 14 victories on red side
# anonymous 162 has 8 victories on blue side
#
# anonymous 162 has 36.36 win rate on blue side
# anonymous 162 has 63.64 win rate on red side
#
# -------------------------------------------
#
# anonymous 163 has a total of 24 victories
#
# anonymous 163 has 8 victories on red side
# anonymous 163 has 16 victories on blue side
#
# anonymous 163 has 66.67 win rate on blue side
# anonymous 163 has 33.33 win rate on red side
#
# -------------------------------------------
#
# anonymous 164 has a total of 45 victories
#
# anonymous 164 has 19 victories on red side
# anonymous 164 has 26 victories on blue side
#
# anonymous 164 has 57.78 win rate on blue side
# anonymous 164 has 42.22 win rate on red side
#
# -------------------------------------------
#
# anonymous 165 has a total of 43 victories
#
# anonymous 165 has 19 victories on red side
# anonymous 165 has 24 victories on blue side
#
# anonymous 165 has 55.81 win rate on blue side
# anonymous 165 has 44.19 win rate on red side
#
# -------------------------------------------
#
# anonymous 166 has a total of 20 victories
#
# anonymous 166 has 12 victories on red side
# anonymous 166 has 8 victories on blue side
#
# anonymous 166 has 40.00 win rate on blue side
# anonymous 166 has 60.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 167 has a total of 33 victories
#
# anonymous 167 has 12 victories on red side
# anonymous 167 has 21 victories on blue side
#
# anonymous 167 has 63.64 win rate on blue side
# anonymous 167 has 36.36 win rate on red side
#
# -------------------------------------------
#
# anonymous 168 has a total of 48 victories
#
# anonymous 168 has 25 victories on red side
# anonymous 168 has 23 victories on blue side
#
# anonymous 168 has 47.92 win rate on blue side
# anonymous 168 has 52.08 win rate on red side
#
# -------------------------------------------
#
# anonymous 17 has a total of 17 victories
#
# anonymous 17 has 10 victories on red side
# anonymous 17 has 7 victories on blue side
#
# anonymous 17 has 41.18 win rate on blue side
# anonymous 17 has 58.82 win rate on red side
#
# -------------------------------------------
#
# anonymous 170 has a total of 13 victories
#
# anonymous 170 has 9 victories on red side
# anonymous 170 has 4 victories on blue side
#
# anonymous 170 has 30.77 win rate on blue side
# anonymous 170 has 69.23 win rate on red side
#
# -------------------------------------------
#
# anonymous 171 has a total of 7 victories
#
# anonymous 171 has 3 victories on red side
# anonymous 171 has 4 victories on blue side
#
# anonymous 171 has 57.14 win rate on blue side
# anonymous 171 has 42.86 win rate on red side
#
# -------------------------------------------
#
# anonymous 172 has a total of 40 victories
#
# anonymous 172 has 18 victories on red side
# anonymous 172 has 22 victories on blue side
#
# anonymous 172 has 55.00 win rate on blue side
# anonymous 172 has 45.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 173 has a total of 25 victories
#
# anonymous 173 has 10 victories on red side
# anonymous 173 has 15 victories on blue side
#
# anonymous 173 has 60.00 win rate on blue side
# anonymous 173 has 40.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 174 has a total of 17 victories
#
# anonymous 174 has 6 victories on red side
# anonymous 174 has 11 victories on blue side
#
# anonymous 174 has 64.71 win rate on blue side
# anonymous 174 has 35.29 win rate on red side
#
# -------------------------------------------
#
# anonymous 175 has a total of 13 victories
#
# anonymous 175 has 8 victories on red side
# anonymous 175 has 5 victories on blue side
#
# anonymous 175 has 38.46 win rate on blue side
# anonymous 175 has 61.54 win rate on red side
#
# -------------------------------------------
#
# anonymous 176 has a total of 29 victories
#
# anonymous 176 has 15 victories on red side
# anonymous 176 has 14 victories on blue side
#
# anonymous 176 has 48.28 win rate on blue side
# anonymous 176 has 51.72 win rate on red side
#
# -------------------------------------------
#
# anonymous 177 has a total of 13 victories
#
# anonymous 177 has 7 victories on red side
# anonymous 177 has 6 victories on blue side
#
# anonymous 177 has 46.15 win rate on blue side
# anonymous 177 has 53.85 win rate on red side
#
# -------------------------------------------
#
# anonymous 178 has a total of 22 victories
#
# anonymous 178 has 13 victories on red side
# anonymous 178 has 9 victories on blue side
#
# anonymous 178 has 40.91 win rate on blue side
# anonymous 178 has 59.09 win rate on red side
#
# -------------------------------------------
#
# anonymous 179 has a total of 9 victories
#
# anonymous 179 has 1 victories on red side
# anonymous 179 has 8 victories on blue side
#
# anonymous 179 has 88.89 win rate on blue side
# anonymous 179 has 11.11 win rate on red side
#
# -------------------------------------------
#
# anonymous 18 has a total of 35 victories
#
# anonymous 18 has 16 victories on red side
# anonymous 18 has 19 victories on blue side
#
# anonymous 18 has 54.29 win rate on blue side
# anonymous 18 has 45.71 win rate on red side
#
# -------------------------------------------
#
# anonymous 180 has a total of 23 victories
#
# anonymous 180 has 9 victories on red side
# anonymous 180 has 14 victories on blue side
#
# anonymous 180 has 60.87 win rate on blue side
# anonymous 180 has 39.13 win rate on red side
#
# -------------------------------------------
#
# anonymous 181 has a total of 22 victories
#
# anonymous 181 has 13 victories on red side
# anonymous 181 has 9 victories on blue side
#
# anonymous 181 has 40.91 win rate on blue side
# anonymous 181 has 59.09 win rate on red side
#
# -------------------------------------------
#
# anonymous 19 has a total of 29 victories
#
# anonymous 19 has 9 victories on red side
# anonymous 19 has 20 victories on blue side
#
# anonymous 19 has 68.97 win rate on blue side
# anonymous 19 has 31.03 win rate on red side
#
# -------------------------------------------
#
# anonymous 2 has a total of 22 victories
#
# anonymous 2 has 13 victories on red side
# anonymous 2 has 9 victories on blue side
#
# anonymous 2 has 40.91 win rate on blue side
# anonymous 2 has 59.09 win rate on red side
#
# -------------------------------------------
#
# anonymous 20 has a total of 20 victories
#
# anonymous 20 has 5 victories on red side
# anonymous 20 has 15 victories on blue side
#
# anonymous 20 has 75.00 win rate on blue side
# anonymous 20 has 25.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 21 has a total of 25 victories
#
# anonymous 21 has 10 victories on red side
# anonymous 21 has 15 victories on blue side
#
# anonymous 21 has 60.00 win rate on blue side
# anonymous 21 has 40.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 22 has a total of 32 victories
#
# anonymous 22 has 17 victories on red side
# anonymous 22 has 15 victories on blue side
#
# anonymous 22 has 46.88 win rate on blue side
# anonymous 22 has 53.12 win rate on red side
#
# -------------------------------------------
#
# anonymous 23 has a total of 24 victories
#
# anonymous 23 has 16 victories on red side
# anonymous 23 has 8 victories on blue side
#
# anonymous 23 has 33.33 win rate on blue side
# anonymous 23 has 66.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 24 has a total of 40 victories
#
# anonymous 24 has 15 victories on red side
# anonymous 24 has 25 victories on blue side
#
# anonymous 24 has 62.50 win rate on blue side
# anonymous 24 has 37.50 win rate on red side
#
# -------------------------------------------
#
# anonymous 25 has a total of 22 victories
#
# anonymous 25 has 13 victories on red side
# anonymous 25 has 9 victories on blue side
#
# anonymous 25 has 40.91 win rate on blue side
# anonymous 25 has 59.09 win rate on red side
#
# -------------------------------------------
#
# anonymous 26 has a total of 33 victories
#
# anonymous 26 has 22 victories on red side
# anonymous 26 has 11 victories on blue side
#
# anonymous 26 has 33.33 win rate on blue side
# anonymous 26 has 66.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 27 has a total of 16 victories
#
# anonymous 27 has 10 victories on red side
# anonymous 27 has 6 victories on blue side
#
# anonymous 27 has 37.50 win rate on blue side
# anonymous 27 has 62.50 win rate on red side
#
# -------------------------------------------
#
# anonymous 28 has a total of 25 victories
#
# anonymous 28 has 9 victories on red side
# anonymous 28 has 16 victories on blue side
#
# anonymous 28 has 64.00 win rate on blue side
# anonymous 28 has 36.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 29 has a total of 26 victories
#
# anonymous 29 has 16 victories on red side
# anonymous 29 has 10 victories on blue side
#
# anonymous 29 has 38.46 win rate on blue side
# anonymous 29 has 61.54 win rate on red side
#
# -------------------------------------------
#
# anonymous 3 has a total of 11 victories
#
# anonymous 3 has 5 victories on red side
# anonymous 3 has 6 victories on blue side
#
# anonymous 3 has 54.55 win rate on blue side
# anonymous 3 has 45.45 win rate on red side
#
# -------------------------------------------
#
# anonymous 30 has a total of 40 victories
#
# anonymous 30 has 20 victories on red side
# anonymous 30 has 20 victories on blue side
#
# anonymous 30 has 50.00 win rate on blue side
# anonymous 30 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 31 has a total of 31 victories
#
# anonymous 31 has 18 victories on red side
# anonymous 31 has 13 victories on blue side
#
# anonymous 31 has 41.94 win rate on blue side
# anonymous 31 has 58.06 win rate on red side
#
# -------------------------------------------
#
# anonymous 32 has a total of 16 victories
#
# anonymous 32 has 9 victories on red side
# anonymous 32 has 7 victories on blue side
#
# anonymous 32 has 43.75 win rate on blue side
# anonymous 32 has 56.25 win rate on red side
#
# -------------------------------------------
#
# anonymous 33 has a total of 17 victories
#
# anonymous 33 has 10 victories on red side
# anonymous 33 has 7 victories on blue side
#
# anonymous 33 has 41.18 win rate on blue side
# anonymous 33 has 58.82 win rate on red side
#
# -------------------------------------------
#
# anonymous 34 has a total of 45 victories
#
# anonymous 34 has 26 victories on red side
# anonymous 34 has 19 victories on blue side
#
# anonymous 34 has 42.22 win rate on blue side
# anonymous 34 has 57.78 win rate on red side
#
# -------------------------------------------
#
# anonymous 35 has a total of 57 victories
#
# anonymous 35 has 23 victories on red side
# anonymous 35 has 34 victories on blue side
#
# anonymous 35 has 59.65 win rate on blue side
# anonymous 35 has 40.35 win rate on red side
#
# -------------------------------------------
#
# anonymous 36 has a total of 11 victories
#
# anonymous 36 has 5 victories on red side
# anonymous 36 has 6 victories on blue side
#
# anonymous 36 has 54.55 win rate on blue side
# anonymous 36 has 45.45 win rate on red side
#
# -------------------------------------------
#
# anonymous 37 has a total of 29 victories
#
# anonymous 37 has 16 victories on red side
# anonymous 37 has 13 victories on blue side
#
# anonymous 37 has 44.83 win rate on blue side
# anonymous 37 has 55.17 win rate on red side
#
# -------------------------------------------
#
# anonymous 38 has a total of 53 victories
#
# anonymous 38 has 22 victories on red side
# anonymous 38 has 31 victories on blue side
#
# anonymous 38 has 58.49 win rate on blue side
# anonymous 38 has 41.51 win rate on red side
#
# -------------------------------------------
#
# anonymous 39 has a total of 38 victories
#
# anonymous 39 has 22 victories on red side
# anonymous 39 has 16 victories on blue side
#
# anonymous 39 has 42.11 win rate on blue side
# anonymous 39 has 57.89 win rate on red side
#
# -------------------------------------------
#
# anonymous 4 has a total of 68 victories
#
# anonymous 4 has 28 victories on red side
# anonymous 4 has 40 victories on blue side
#
# anonymous 4 has 58.82 win rate on blue side
# anonymous 4 has 41.18 win rate on red side
#
# -------------------------------------------
#
# anonymous 40 has a total of 14 victories
#
# anonymous 40 has 8 victories on red side
# anonymous 40 has 6 victories on blue side
#
# anonymous 40 has 42.86 win rate on blue side
# anonymous 40 has 57.14 win rate on red side
#
# -------------------------------------------
#
# anonymous 41 has a total of 50 victories
#
# anonymous 41 has 20 victories on red side
# anonymous 41 has 30 victories on blue side
#
# anonymous 41 has 60.00 win rate on blue side
# anonymous 41 has 40.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 42 has a total of 25 victories
#
# anonymous 42 has 11 victories on red side
# anonymous 42 has 14 victories on blue side
#
# anonymous 42 has 56.00 win rate on blue side
# anonymous 42 has 44.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 43 has a total of 27 victories
#
# anonymous 43 has 15 victories on red side
# anonymous 43 has 12 victories on blue side
#
# anonymous 43 has 44.44 win rate on blue side
# anonymous 43 has 55.56 win rate on red side
#
# -------------------------------------------
#
# anonymous 44 has a total of 23 victories
#
# anonymous 44 has 14 victories on red side
# anonymous 44 has 9 victories on blue side
#
# anonymous 44 has 39.13 win rate on blue side
# anonymous 44 has 60.87 win rate on red side
#
# -------------------------------------------
#
# anonymous 45 has a total of 62 victories
#
# anonymous 45 has 33 victories on red side
# anonymous 45 has 29 victories on blue side
#
# anonymous 45 has 46.77 win rate on blue side
# anonymous 45 has 53.23 win rate on red side
#
# -------------------------------------------
#
# anonymous 46 has a total of 26 victories
#
# anonymous 46 has 18 victories on red side
# anonymous 46 has 8 victories on blue side
#
# anonymous 46 has 30.77 win rate on blue side
# anonymous 46 has 69.23 win rate on red side
#
# -------------------------------------------
#
# anonymous 47 has a total of 28 victories
#
# anonymous 47 has 13 victories on red side
# anonymous 47 has 15 victories on blue side
#
# anonymous 47 has 53.57 win rate on blue side
# anonymous 47 has 46.43 win rate on red side
#
# -------------------------------------------
#
# anonymous 48 has a total of 33 victories
#
# anonymous 48 has 16 victories on red side
# anonymous 48 has 17 victories on blue side
#
# anonymous 48 has 51.52 win rate on blue side
# anonymous 48 has 48.48 win rate on red side
#
# -------------------------------------------
#
# anonymous 49 has a total of 15 victories
#
# anonymous 49 has 9 victories on red side
# anonymous 49 has 6 victories on blue side
#
# anonymous 49 has 40.00 win rate on blue side
# anonymous 49 has 60.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 5 has a total of 22 victories
#
# anonymous 5 has 15 victories on red side
# anonymous 5 has 7 victories on blue side
#
# anonymous 5 has 31.82 win rate on blue side
# anonymous 5 has 68.18 win rate on red side
#
# -------------------------------------------
#
# anonymous 50 has a total of 40 victories
#
# anonymous 50 has 21 victories on red side
# anonymous 50 has 19 victories on blue side
#
# anonymous 50 has 47.50 win rate on blue side
# anonymous 50 has 52.50 win rate on red side
#
# -------------------------------------------
#
# anonymous 51 has a total of 64 victories
#
# anonymous 51 has 31 victories on red side
# anonymous 51 has 33 victories on blue side
#
# anonymous 51 has 51.56 win rate on blue side
# anonymous 51 has 48.44 win rate on red side
#
# -------------------------------------------
#
# anonymous 52 has a total of 20 victories
#
# anonymous 52 has 9 victories on red side
# anonymous 52 has 11 victories on blue side
#
# anonymous 52 has 55.00 win rate on blue side
# anonymous 52 has 45.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 53 has a total of 49 victories
#
# anonymous 53 has 29 victories on red side
# anonymous 53 has 20 victories on blue side
#
# anonymous 53 has 40.82 win rate on blue side
# anonymous 53 has 59.18 win rate on red side
#
# -------------------------------------------
#
# anonymous 54 has a total of 54 victories
#
# anonymous 54 has 34 victories on red side
# anonymous 54 has 20 victories on blue side
#
# anonymous 54 has 37.04 win rate on blue side
# anonymous 54 has 62.96 win rate on red side
#
# -------------------------------------------
#
# anonymous 55 has a total of 24 victories
#
# anonymous 55 has 12 victories on red side
# anonymous 55 has 12 victories on blue side
#
# anonymous 55 has 50.00 win rate on blue side
# anonymous 55 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 56 has a total of 16 victories
#
# anonymous 56 has 10 victories on red side
# anonymous 56 has 6 victories on blue side
#
# anonymous 56 has 37.50 win rate on blue side
# anonymous 56 has 62.50 win rate on red side
#
# -------------------------------------------
#
# anonymous 57 has a total of 49 victories
#
# anonymous 57 has 27 victories on red side
# anonymous 57 has 22 victories on blue side
#
# anonymous 57 has 44.90 win rate on blue side
# anonymous 57 has 55.10 win rate on red side
#
# -------------------------------------------
#
# anonymous 58 has a total of 32 victories
#
# anonymous 58 has 17 victories on red side
# anonymous 58 has 15 victories on blue side
#
# anonymous 58 has 46.88 win rate on blue side
# anonymous 58 has 53.12 win rate on red side
#
# -------------------------------------------
#
# anonymous 59 has a total of 36 victories
#
# anonymous 59 has 18 victories on red side
# anonymous 59 has 18 victories on blue side
#
# anonymous 59 has 50.00 win rate on blue side
# anonymous 59 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 6 has a total of 36 victories
#
# anonymous 6 has 24 victories on red side
# anonymous 6 has 12 victories on blue side
#
# anonymous 6 has 33.33 win rate on blue side
# anonymous 6 has 66.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 60 has a total of 35 victories
#
# anonymous 60 has 18 victories on red side
# anonymous 60 has 17 victories on blue side
#
# anonymous 60 has 48.57 win rate on blue side
# anonymous 60 has 51.43 win rate on red side
#
# -------------------------------------------
#
# anonymous 62 has a total of 33 victories
#
# anonymous 62 has 21 victories on red side
# anonymous 62 has 12 victories on blue side
#
# anonymous 62 has 36.36 win rate on blue side
# anonymous 62 has 63.64 win rate on red side
#
# -------------------------------------------
#
# anonymous 63 has a total of 34 victories
#
# anonymous 63 has 17 victories on red side
# anonymous 63 has 17 victories on blue side
#
# anonymous 63 has 50.00 win rate on blue side
# anonymous 63 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 64 has a total of 45 victories
#
# anonymous 64 has 21 victories on red side
# anonymous 64 has 24 victories on blue side
#
# anonymous 64 has 53.33 win rate on blue side
# anonymous 64 has 46.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 65 has a total of 23 victories
#
# anonymous 65 has 8 victories on red side
# anonymous 65 has 15 victories on blue side
#
# anonymous 65 has 65.22 win rate on blue side
# anonymous 65 has 34.78 win rate on red side
#
# -------------------------------------------
#
# anonymous 66 has a total of 61 victories
#
# anonymous 66 has 35 victories on red side
# anonymous 66 has 26 victories on blue side
#
# anonymous 66 has 42.62 win rate on blue side
# anonymous 66 has 57.38 win rate on red side
#
# -------------------------------------------
#
# anonymous 67 has a total of 26 victories
#
# anonymous 67 has 12 victories on red side
# anonymous 67 has 14 victories on blue side
#
# anonymous 67 has 53.85 win rate on blue side
# anonymous 67 has 46.15 win rate on red side
#
# -------------------------------------------
#
# anonymous 68 has a total of 26 victories
#
# anonymous 68 has 10 victories on red side
# anonymous 68 has 16 victories on blue side
#
# anonymous 68 has 61.54 win rate on blue side
# anonymous 68 has 38.46 win rate on red side
#
# -------------------------------------------
#
# anonymous 69 has a total of 41 victories
#
# anonymous 69 has 17 victories on red side
# anonymous 69 has 24 victories on blue side
#
# anonymous 69 has 58.54 win rate on blue side
# anonymous 69 has 41.46 win rate on red side
#
# -------------------------------------------
#
# anonymous 7 has a total of 44 victories
#
# anonymous 7 has 24 victories on red side
# anonymous 7 has 20 victories on blue side
#
# anonymous 7 has 45.45 win rate on blue side
# anonymous 7 has 54.55 win rate on red side
#
# -------------------------------------------
#
# anonymous 70 has a total of 39 victories
#
# anonymous 70 has 14 victories on red side
# anonymous 70 has 25 victories on blue side
#
# anonymous 70 has 64.10 win rate on blue side
# anonymous 70 has 35.90 win rate on red side
#
# -------------------------------------------
#
# anonymous 71 has a total of 23 victories
#
# anonymous 71 has 11 victories on red side
# anonymous 71 has 12 victories on blue side
#
# anonymous 71 has 52.17 win rate on blue side
# anonymous 71 has 47.83 win rate on red side
#
# -------------------------------------------
#
# anonymous 72 has a total of 49 victories
#
# anonymous 72 has 20 victories on red side
# anonymous 72 has 29 victories on blue side
#
# anonymous 72 has 59.18 win rate on blue side
# anonymous 72 has 40.82 win rate on red side
#
# -------------------------------------------
#
# anonymous 73 has a total of 41 victories
#
# anonymous 73 has 18 victories on red side
# anonymous 73 has 23 victories on blue side
#
# anonymous 73 has 56.10 win rate on blue side
# anonymous 73 has 43.90 win rate on red side
#
# -------------------------------------------
#
# anonymous 74 has a total of 46 victories
#
# anonymous 74 has 23 victories on red side
# anonymous 74 has 23 victories on blue side
#
# anonymous 74 has 50.00 win rate on blue side
# anonymous 74 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 75 has a total of 34 victories
#
# anonymous 75 has 18 victories on red side
# anonymous 75 has 16 victories on blue side
#
# anonymous 75 has 47.06 win rate on blue side
# anonymous 75 has 52.94 win rate on red side
#
# -------------------------------------------
#
# anonymous 76 has a total of 49 victories
#
# anonymous 76 has 23 victories on red side
# anonymous 76 has 26 victories on blue side
#
# anonymous 76 has 53.06 win rate on blue side
# anonymous 76 has 46.94 win rate on red side
#
# -------------------------------------------
#
# anonymous 77 has a total of 33 victories
#
# anonymous 77 has 12 victories on red side
# anonymous 77 has 21 victories on blue side
#
# anonymous 77 has 63.64 win rate on blue side
# anonymous 77 has 36.36 win rate on red side
#
# -------------------------------------------
#
# anonymous 78 has a total of 37 victories
#
# anonymous 78 has 16 victories on red side
# anonymous 78 has 21 victories on blue side
#
# anonymous 78 has 56.76 win rate on blue side
# anonymous 78 has 43.24 win rate on red side
#
# -------------------------------------------
#
# anonymous 79 has a total of 30 victories
#
# anonymous 79 has 17 victories on red side
# anonymous 79 has 13 victories on blue side
#
# anonymous 79 has 43.33 win rate on blue side
# anonymous 79 has 56.67 win rate on red side
#
# -------------------------------------------
#
# anonymous 8 has a total of 45 victories
#
# anonymous 8 has 28 victories on red side
# anonymous 8 has 17 victories on blue side
#
# anonymous 8 has 37.78 win rate on blue side
# anonymous 8 has 62.22 win rate on red side
#
# -------------------------------------------
#
# anonymous 80 has a total of 52 victories
#
# anonymous 80 has 26 victories on red side
# anonymous 80 has 26 victories on blue side
#
# anonymous 80 has 50.00 win rate on blue side
# anonymous 80 has 50.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 81 has a total of 47 victories
#
# anonymous 81 has 26 victories on red side
# anonymous 81 has 21 victories on blue side
#
# anonymous 81 has 44.68 win rate on blue side
# anonymous 81 has 55.32 win rate on red side
#
# -------------------------------------------
#
# anonymous 83 has a total of 39 victories
#
# anonymous 83 has 21 victories on red side
# anonymous 83 has 18 victories on blue side
#
# anonymous 83 has 46.15 win rate on blue side
# anonymous 83 has 53.85 win rate on red side
#
# -------------------------------------------
#
# anonymous 84 has a total of 44 victories
#
# anonymous 84 has 19 victories on red side
# anonymous 84 has 25 victories on blue side
#
# anonymous 84 has 56.82 win rate on blue side
# anonymous 84 has 43.18 win rate on red side
#
# -------------------------------------------
#
# anonymous 85 has a total of 44 victories
#
# anonymous 85 has 21 victories on red side
# anonymous 85 has 23 victories on blue side
#
# anonymous 85 has 52.27 win rate on blue side
# anonymous 85 has 47.73 win rate on red side
#
# -------------------------------------------
#
# anonymous 86 has a total of 47 victories
#
# anonymous 86 has 28 victories on red side
# anonymous 86 has 19 victories on blue side
#
# anonymous 86 has 40.43 win rate on blue side
# anonymous 86 has 59.57 win rate on red side
#
# -------------------------------------------
#
# anonymous 87 has a total of 37 victories
#
# anonymous 87 has 19 victories on red side
# anonymous 87 has 18 victories on blue side
#
# anonymous 87 has 48.65 win rate on blue side
# anonymous 87 has 51.35 win rate on red side
#
# -------------------------------------------
#
# anonymous 88 has a total of 46 victories
#
# anonymous 88 has 29 victories on red side
# anonymous 88 has 17 victories on blue side
#
# anonymous 88 has 36.96 win rate on blue side
# anonymous 88 has 63.04 win rate on red side
#
# -------------------------------------------
#
# anonymous 89 has a total of 50 victories
#
# anonymous 89 has 24 victories on red side
# anonymous 89 has 26 victories on blue side
#
# anonymous 89 has 52.00 win rate on blue side
# anonymous 89 has 48.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 9 has a total of 26 victories
#
# anonymous 9 has 9 victories on red side
# anonymous 9 has 17 victories on blue side
#
# anonymous 9 has 65.38 win rate on blue side
# anonymous 9 has 34.62 win rate on red side
#
# -------------------------------------------
#
# anonymous 90 has a total of 25 victories
#
# anonymous 90 has 15 victories on red side
# anonymous 90 has 10 victories on blue side
#
# anonymous 90 has 40.00 win rate on blue side
# anonymous 90 has 60.00 win rate on red side
#
# -------------------------------------------
#
# anonymous 91 has a total of 47 victories
#
# anonymous 91 has 22 victories on red side
# anonymous 91 has 25 victories on blue side
#
# anonymous 91 has 53.19 win rate on blue side
# anonymous 91 has 46.81 win rate on red side
#
# -------------------------------------------
#
# anonymous 92 has a total of 14 victories
#
# anonymous 92 has 8 victories on red side
# anonymous 92 has 6 victories on blue side
#
# anonymous 92 has 42.86 win rate on blue side
# anonymous 92 has 57.14 win rate on red side
#
# -------------------------------------------
#
# anonymous 93 has a total of 52 victories
#
# anonymous 93 has 31 victories on red side
# anonymous 93 has 21 victories on blue side
#
# anonymous 93 has 40.38 win rate on blue side
# anonymous 93 has 59.62 win rate on red side
#
# -------------------------------------------
#
# anonymous 94 has a total of 16 victories
#
# anonymous 94 has 9 victories on red side
# anonymous 94 has 7 victories on blue side
#
# anonymous 94 has 43.75 win rate on blue side
# anonymous 94 has 56.25 win rate on red side
#
# -------------------------------------------
#
# anonymous 95 has a total of 29 victories
#
# anonymous 95 has 13 victories on red side
# anonymous 95 has 16 victories on blue side
#
# anonymous 95 has 55.17 win rate on blue side
# anonymous 95 has 44.83 win rate on red side
#
# -------------------------------------------
#
# anonymous 96 has a total of 41 victories
#
# anonymous 96 has 24 victories on red side
# anonymous 96 has 17 victories on blue side
#
# anonymous 96 has 41.46 win rate on blue side
# anonymous 96 has 58.54 win rate on red side
#
# -------------------------------------------
#
# anonymous 98 has a total of 14 victories
#
# anonymous 98 has 9 victories on red side
# anonymous 98 has 5 victories on blue side
#
# anonymous 98 has 35.71 win rate on blue side
# anonymous 98 has 64.29 win rate on red side
#
# -------------------------------------------
#
# anonymous 99 has a total of 23 victories
#
# anonymous 99 has 15 victories on red side
# anonymous 99 has 8 victories on blue side
#
# anonymous 99 has 34.78 win rate on blue side
# anonymous 99 has 65.22 win rate on red side
#
# -------------------------------------------
